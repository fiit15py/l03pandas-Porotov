# %%
import pandas as pd

# %%
df = pd.read_csv('ulus.csv')
df.head()
# Out:
#   Улус;Администр. центр;Площадь  тыс.км2;Численность населения (2002  г.)  \
# 0     Абыйский;п. Белая Гора;69      4;4750;1950/2900;3243;1148;-;-;1;6;5
# 1        Алданский;г. Алдан;156              8;49346;534;-;470;-;2;4;13;3
# 2  Аллаиховский;п. Чокурдах;107           3;3421;2700;2830;1290;-;-;1;6;5
# 3          Амгинский;с. Амга;29          4;17251;201;1036;200;-;-;-;21;14
# 4     Анабарский;с. Саскылах;55           6;4024;2621;2835;1285;-;-;-;3;3
#
#     чел;Расст до Якт наземным;Расст до Якт водным;Расст до Якт воздушным;городов респ;городов улусного;поселков;сел;наслегов
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
df = pd.read_csv('ulus.csv', sep=';')
df.head()
# Out:
#            Улус Администр. центр Площадь, тыс.км2  \
# 0      Абыйский    п. Белая Гора             69,4
# 1     Алданский         г. Алдан            156,8
# 2  Аллаиховский      п. Чокурдах            107,3
# 3     Амгинский          с. Амга             29,4
# 4    Анабарский      с. Саскылах             55,6
#
#    Численность населения (2002  г.), чел Расст до Якт наземным  \
# 0                                 4750.0             1950/2900
# 1                                49346.0                   534
# 2                                 3421.0                  2700
# 3                                17251.0                   201
# 4                                 4024.0                  2621
#
#   Расст до Якт водным Расст до Якт воздушным городов респ городов улусного  \
# 0                3243                   1148            -                -
# 1                   -                    470            -                2
# 2                2830                   1290            -                -
# 3                1036                    200            -                -
# 4                2835                   1285            -                -
#
#   поселков   сел  наслегов
# 0        1   6.0       5.0
# 1        4  13.0       3.0
# 2        1   6.0       5.0
# 3        -  21.0      14.0
# 4        -   3.0       3.0

# %%
df.dtypes
# Out:
# Улус                                      object
# Администр. центр                          object
# Площадь, тыс.км2                          object
# Численность населения (2002  г.), чел    float64
# Расст до Якт наземным                     object
# Расст до Якт водным                       object
# Расст до Якт воздушным                    object
# городов респ                              object
# городов улусного                          object
# поселков                                  object
# сел                                      float64
# наслегов                                 float64
# area                                      object
# density                                   object
# dtype: object

# %%
df.columns
# Out:
# Index(['Улус', 'Администр. центр', 'Площадь, тыс.км2',
#        'Численность населения (2002  г.), чел', 'Расст до Якт наземным',
#        'Расст до Якт водным', 'Расст до Якт воздушным', 'городов респ',
#        'городов улусного', 'поселков', 'сел', 'наслегов'],
#       dtype='object')

# %%
df['сел']
# Out:
# 0      6.0
# 1     13.0
# 2      6.0
# 3     21.0
# 4      3.0
# 5      9.0
# 6     29.0
# 7      5.0
# 8     26.0
# 9     25.0
# 10    16.0
# 11     5.0
# 12    22.0
# 13    16.0
# 14    35.0
# 15     8.0
# 16     7.0
# 17    24.0
# 18     2.0
# 19    12.0
# 20    23.0
# 21    13.0
# 22    52.0
# 23     4.0
# 24     NaN
# 25    14.0
# 26    39.0
# 27    15.0
# 28    12.0
# 29    35.0
# 30    10.0
# 31     7.0
# 32    27.0
# 33    30.0
# 34     4.0
# 35    11.0
# Name: сел, dtype: float64

# %%
df.head()
# Out:
#            Улус Администр. центр Площадь, тыс.км2  \
# 0      Абыйский    п. Белая Гора             69,4
# 1     Алданский         г. Алдан            156,8
# 2  Аллаиховский      п. Чокурдах            107,3
# 3     Амгинский          с. Амга             29,4
# 4    Анабарский      с. Саскылах             55,6
#
#    Численность населения (2002  г.), чел Расст до Якт наземным  \
# 0                                 4750.0             1950/2900
# 1                                49346.0                   534
# 2                                 3421.0                  2700
# 3                                17251.0                   201
# 4                                 4024.0                  2621
#
#   Расст до Якт водным Расст до Якт воздушным городов респ городов улусного  \
# 0                3243                   1148            -                -
# 1                   -                    470            -                2
# 2                2830                   1290            -                -
# 3                1036                    200            -                -
# 4                2835                   1285            -                -
#
#   поселков   сел  наслегов   area density
# 0        1   6.0       5.0   69,4    69,4
# 1        4  13.0       3.0  156,8   156,8
# 2        1   6.0       5.0  107,3   107,3
# 3        -  21.0      14.0   29,4    29,4
# 4        -   3.0       3.0   55,6    55,6

# %%
df['area'] = df['Площадь, тыс.км2']

# %%
df.head()
# Out:
#            Улус Администр. центр Площадь, тыс.км2  \
# 0      Абыйский    п. Белая Гора             69,4
# 1     Алданский         г. Алдан            156,8
# 2  Аллаиховский      п. Чокурдах            107,3
# 3     Амгинский          с. Амга             29,4
# 4    Анабарский      с. Саскылах             55,6
#
#    Численность населения (2002  г.), чел Расст до Якт наземным  \
# 0                                 4750.0             1950/2900
# 1                                49346.0                   534
# 2                                 3421.0                  2700
# 3                                17251.0                   201
# 4                                 4024.0                  2621
#
#   Расст до Якт водным Расст до Якт воздушным городов респ городов улусного  \
# 0                3243                   1148            -                -
# 1                   -                    470            -                2
# 2                2830                   1290            -                -
# 3                1036                    200            -                -
# 4                2835                   1285            -                -
#
#   поселков   сел  наслегов   area density
# 0        1   6.0       5.0   69,4    69,4
# 1        4  13.0       3.0  156,8   156,8
# 2        1   6.0       5.0  107,3   107,3
# 3        -  21.0      14.0   29,4    29,4
# 4        -   3.0       3.0   55,6    55,6

# %%
df['area'] = df['Площадь, тыс.км2']

# %%
df['area'].replace()
# Out:
# 0      69,4
# 1     156,8
# 2     107,3
# 3      29,4
# 4      55,6
# 5     223,6
# 6        42
# 7      67,8
# 8     137,4
# 9      55,2
# 10     45,6
# 11    140,2
# 12    107,8
# 13       77
# 14     11,7
# 15    165,8
# 16    104,6
# 17     11,9
# 18     98,9
# 19     87,1
# 20     52,4
# 21     92,3
# 22    160,8
# 23      318
# 24      318
# 25    125,2
# 26     57,8
# 27       19
# 28    135,8
# 29     18,3
# 30     95,3
# 31    120,3
# 32     24,7
# 33     12,6
# 34     52,3
# 35      3,6
# Name: area, dtype: object

# %%
def replace_comma(s):
    return s.replace(',','.') if type(s)==str else '0'

# %%
df['area']=df['Площадь, тыс.км2'].apply(replace_comma)

# %%
df['area']=df['area'].astype(float)

# %%
df.head()
# Out:
#            Улус Администр. центр Площадь, тыс.км2  \
# 0      Абыйский    п. Белая Гора             69,4
# 1     Алданский         г. Алдан            156,8
# 2  Аллаиховский      п. Чокурдах            107,3
# 3     Амгинский          с. Амга             29,4
# 4    Анабарский      с. Саскылах             55,6
#
#    Численность населения (2002  г.), чел Расст до Якт наземным  \
# 0                                 4750.0             1950/2900
# 1                                49346.0                   534
# 2                                 3421.0                  2700
# 3                                17251.0                   201
# 4                                 4024.0                  2621
#
#   Расст до Якт водным Расст до Якт воздушным городов респ городов улусного  \
# 0                3243                   1148            -                -
# 1                   -                    470            -                2
# 2                2830                   1290            -                -
# 3                1036                    200            -                -
# 4                2835                   1285            -                -
#
#   поселков   сел  наслегов   area density
# 0        1   6.0       5.0   69.4    69,4
# 1        4  13.0       3.0  156.8   156,8
# 2        1   6.0       5.0  107.3   107,3
# 3        -  21.0      14.0   29.4    29,4
# 4        -   3.0       3.0   55.6    55,6

# %%
df.dtypes
# Out:
# Улус                                      object
# Администр. центр                          object
# Площадь, тыс.км2                          object
# Численность населения (2002  г.), чел    float64
# Расст до Якт наземным                     object
# Расст до Якт водным                       object
# Расст до Якт воздушным                    object
# городов респ                              object
# городов улусного                          object
# поселков                                  object
# сел                                      float64
# наслегов                                 float64
# area                                     float64
# density                                  float64
# dtype: object

# %%
df['density']=df['Площадь, тыс.км2'].apply(replace_comma)

# %%
df['density']=df['density'].astype(float)

# %%
df.head()
# Out:
#            Улус Администр. центр Площадь, тыс.км2  \
# 0      Абыйский    п. Белая Гора             69,4
# 1     Алданский         г. Алдан            156,8
# 2  Аллаиховский      п. Чокурдах            107,3
# 3     Амгинский          с. Амга             29,4
# 4    Анабарский      с. Саскылах             55,6
#
#    Численность населения (2002  г.), чел Расст до Якт наземным  \
# 0                                 4750.0             1950/2900
# 1                                49346.0                   534
# 2                                 3421.0                  2700
# 3                                17251.0                   201
# 4                                 4024.0                  2621
#
#   Расст до Якт водным Расст до Якт воздушным городов респ городов улусного  \
# 0                3243                   1148            -                -
# 1                   -                    470            -                2
# 2                2830                   1290            -                -
# 3                1036                    200            -                -
# 4                2835                   1285            -                -
#
#   поселков   сел  наслегов   area  density
# 0        1   6.0       5.0   69.4     69.4
# 1        4  13.0       3.0  156.8    156.8
# 2        1   6.0       5.0  107.3    107.3
# 3        -  21.0      14.0   29.4     29.4
# 4        -   3.0       3.0   55.6     55.6

# %%
df.dtypes
# Out:
# Улус                                      object
# Администр. центр                          object
# Площадь, тыс.км2                          object
# Численность населения (2002  г.), чел    float64
# Расст до Якт наземным                     object
# Расст до Якт водным                       object
# Расст до Якт воздушным                    object
# городов респ                              object
# городов улусного                          object
# поселков                                  object
# сел                                      float64
# наслегов                                 float64
# area                                     float64
# density                                  float64
# dtype: object

# %%
df.drop([24], inplace=True)

# %%
df['density'] = df['Численность населения\xa0(2002\xa0 г.), чел']/(1000*df['area'])

# %%
df.drop(columns=['desnity'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-120-1e65a4fac98b> in <module>()
# ----> 1 df.drop(columns=['desnity'])
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3112
#    3113         if inplace:
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3141                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3142             else:
# -> 3143                 new_axis = axis.drop(labels, errors=errors)
#    3144             result = self.reindex(**{axis_name: new_axis})
#    3145
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    4402             if errors != 'ignore':
#    4403                 raise KeyError(
# -> 4404                     '{} not found in axis'.format(labels[mask]))
#    4405             indexer = indexer[~mask]
#    4406         return self.delete(indexer)
#
# KeyError: "['desnity'] not found in axis"

# %%
df['Улус'][df['density'].idxmin()]
# Out:
# 'Оленекский эвенкийский национальный'

# %%
df.head()
# Out:
#            Улус Администр. центр Площадь, тыс.км2  \
# 0      Абыйский    п. Белая Гора             69,4
# 1     Алданский         г. Алдан            156,8
# 2  Аллаиховский      п. Чокурдах            107,3
# 3     Амгинский          с. Амга             29,4
# 4    Анабарский      с. Саскылах             55,6
#
#    Численность населения (2002  г.), чел Расст до Якт наземным  \
# 0                                 4750.0                  1950
# 1                                49346.0                   534
# 2                                 3421.0                  2700
# 3                                17251.0                   201
# 4                                 4024.0                  2621
#
#   Расст до Якт водным Расст до Якт воздушным городов респ городов улусного  \
# 0                3243                   1148            -                -
# 1                   -                    470            -                2
# 2                2830                   1290            -                -
# 3                1036                    200            -                -
# 4                2835                   1285            -                -
#
#   поселков   сел  наслегов   area   density relation
# 0        1   6.0       5.0   69.4  0.068444     1950
# 1        4  13.0       3.0  156.8  0.314707      534
# 2        1   6.0       5.0  107.3  0.031883     2700
# 3        -  21.0      14.0   29.4  0.586769      201
# 4        -   3.0       3.0   55.6  0.072374     2621

# %%
df['Расст до Якт наземным']=df['Расст до Якт наземным'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-134-3d71e384c052> in <module>()
# ----> 1 df['Расст до Якт наземным']=df['Расст до Якт наземным'].astype(int)
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5001                                          **kwargs)
#    5002             return self._constructor(new_data).__finalize__(self)
#    5003
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\internals.py in astype(self, dtype, **kwargs)
#    3712
#    3713     def astype(self, dtype, **kwargs):
# -> 3714         return self.apply('astype', dtype=dtype, **kwargs)
#    3715
#    3716     def convert(self, **kwargs):
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3579
#    3580             kwargs['mgr'] = self
# -> 3581             applied = getattr(b, f)(**kwargs)
#    3582             result_blocks = _extend_blocks(applied, result_blocks)
#    3583
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\internals.py in astype(self, dtype, copy, errors, values, **kwargs)
#     573     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     574         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 575                             **kwargs)
#     576
#     577     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\internals.py in _astype(self, dtype, copy, errors, values, klass, mgr, **kwargs)
#     662
#     663                 # _astype_nansafe works fine with 1-d only
# --> 664                 values = astype_nansafe(values.ravel(), dtype, copy=True)
#     665                 values = values.reshape(self.shape)
#     666
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy)
#     707         # work around NumPy brokenness, #1987
#     708         if np.issubdtype(dtype.type, np.integer):
# --> 709             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     710
#     711         # if we have a datetime/timedelta array of objects
#
# pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# pandas/_libs/src\util.pxd in util.set_value_at_unsafe()
#
# ValueError: invalid literal for int() with base 10: '334/527'

# %%
df['relation'] = df['Расст до Якт наземным']/df['Расст до Якт воздушным']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1011         try:
# -> 1012             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1013         except TypeError:
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      64     with np.errstate(all='ignore'):
# ---> 65         return op(a, b)
#      66
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#    1032             with np.errstate(all='ignore'):
# -> 1033                 return na_op(lvalues, rvalues)
#    1034         except Exception:
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1017                 mask = notna(x) & notna(y)
# -> 1018                 result[mask] = op(x[mask], com._values_from_object(y[mask]))
#    1019             else:
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-132-de7aa11d7625> in <module>()
# ----> 1 df['relation'] = df['Расст до Якт наземным']/df['Расст до Якт воздушным']
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\ops.py in wrapper(left, right)
#    1067             rvalues = rvalues.values
#    1068
# -> 1069         result = safe_na_op(lvalues, rvalues)
#    1070         return construct_result(left, result,
#    1071                                 index=left.index, name=res_name, dtype=None)
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#    1035             if is_object_dtype(lvalues):
#    1036                 return libalgos.arrmap_object(lvalues,
# -> 1037                                               lambda x: op(x, rvalues))
#    1038             raise
#    1039
#
# pandas\_libs\algos_common_helper.pxi in pandas._libs.algos.arrmap_object()
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\ops.py in <lambda>(x)
#    1035             if is_object_dtype(lvalues):
#    1036                 return libalgos.arrmap_object(lvalues,
# -> 1037                                               lambda x: op(x, rvalues))
#    1038             raise
#    1039
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'
